# %% [markdown]
# <a href="https://colab.research.google.com/github/DametraOwO/Algoritma-Random-Number-Generator-RNG-Pada-Sistem-Gacha-di-Game-Genshin-Impact/blob/main/Algoritma_Random_Number_Generator_(RNG)_Pada_Sistem_Gacha_di_Game_Genshin_Impact.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Genshin Impact adalah game action RPG open world yang dikembangkan oleh Hoyoverse. Game ini menawarkan dunia fantasi bernama Teyvat, yang penuh dengan eksplorasi, teka-teki, dan pertarungan berbasis elemen. Pemain berperan sebagai seorang Traveler yang menjelajahi dunia untuk mencari saudara kembarnya yang hilang, sembari bertemu berbagai karakter dan terlibat dalam cerita epik yang kaya akan tradisi dan misteri.
#
# Sistem Gacha dalam Genshin Impact disebut sebagai "Wish" adalah mekanisme berbasis undian yang memungkinkan pemain untuk memperoleh karakter baru dan senjata langka. Pemain menggunakan currrency dalam game seperti Primogems untuk melakukan wish di banner tertentu. Hasil undian bersifat acak, tetapi game ini memiliki sistem pity yang menjamin pemain akan mendapatkan item bintang 4 setiap 10x wish atau bintang 5 setelah 90x wish. Banner biasanya dibagi menjadi beberapa jenis:
#
# 1.   Character Event Wish: Fokus pada karakter bintang 5 tertentu.
# 2.   Weapon Event Wish: Berisi senjata eksklusif bintang 5.
# 3.   Standard Wish: Pool umum dengan berbagai karakter dan senjata.
#
# Sistem ini menciptakan elemen keberuntungan yang membuat gameplay lebih menarik, meskipun bisa mendorong pemain untuk berinvestasi uang nyata jika ingin mempercepat progress.
#
# Disini saya akan mencoba menghitung persentase kemungkinan player akan mendapatkan item atau karakter bintang 5 sebelum terjamin dapat di undian ke 90.
#
#
# **1. Parameter**

# %%
import matplotlib.pyplot as plt
import numpy as np
a = 17
m = 61
z0 = 3
n = 89

# %% [markdown]
# 𝑎: Konstanta untuk menentukan skala perhitungan.
#
# 𝑚: Modulus untuk memastikan hasil tetap dalam batas tertentu (0 hingga 𝑚 − 1).
#
# z0: nilai awal penghitungan
#
# n: jumlah iterasi yang diinginkan (saya gunakan 90)
#
# Library matplotlib dan numpy digunakan untuk menampilkan grafik di akhir

# %% [markdown]
# **2. Inisialisasi Data (Array)**

# %%
results = []

# %% [markdown]
# results = [] adalah list yang digunakan untuk menyimpan data hasil perhitungan algoritma Random Number Generator (RNG)

# %% [markdown]
# **3. Algoritma RNG**

# %%
z = z0
for i in range(1, n+1):
 z_prev = z
 z = (a * z) % m
 u = z/m
 percentage = round(u * 100, 2)
 rumus = f"(17 * {z_prev}) mod {m}"
 results.append([i, z_prev, rumus, z, round(u, 3), f"{percentage}%"])
results.append([90, "PASTI DAPAT", "PASTI DAPAT", "PASTI DAPAT", 1, "100%"])

# %% [markdown]
# z = z0 Menetapkan nilai awal z0, yang merupakan seed (benih) untuk menghasilkan bilangan acak.
#
# Perulangan for berjalan sebanyak n kali, yaitu dari 1 hingga n (dalam hal ini, 89).
#
# Nilai z saat ini disimpan ke dalam z_prev. Ini digunakan untuk mencetak bilangan acak sebelumnya di tabel hasil.
#
# z = (a * z) % m adalah Rumus LCG digunakan untuk menghitung z baru
#
# u = z / m Nilai u dihitung sebagai rasio z terhadap m, sehingga menghasilkan nilai dalam interval [0, 1], yang menyerupai bilangan acak seragam.
#
# Nilai u dikalikan dengan 100 untuk mengubahnya menjadi persentase.
#
# Hasil perhitungan untuk iterasi saat ini ditambahkan ke dalam list results
#
# Iterasi ke-90 ditambahkan secara manual dengan nilai-nilai khusus:
#
# 90, "PASTI DAPAT", "PASTI DAPAT", "PASTI DAPAT", 1, "100%"
#
# karena dalam sistem wish genshin impact ini, pada wish ke 90 pasti akan mendapatkan item/karakter bintang 5 yang tersedia

# %% [markdown]
# **4. Output dalam bentuk tabel**

# %%
print(f"{'1':<3} | {'zi-1(Bilangan Sebelumnya)':<28} | {'rumus zi = (17,zi-1) mod 61':<32} | {'z (Bilangan Acak)':<20} | {'ui = zi/61 (Bilangan Acak Seragam)':<35} | {'% (Persentase)':<10}")
print("_" * 150)

for row in results:
 print(f"{row[0]:<3} | {row[1]:<28} | {row[2]:<32} | {row[3]:<20} | {row[4]:<35} | {row[5]:<10}")
# Out:
# 1   | zi-1(Bilangan Sebelumnya)    | rumus zi = (17,zi-1) mod 61      | z (Bilangan Acak)    | ui = zi/61 (Bilangan Acak Seragam)  | % (Persentase)
# ______________________________________________________________________________________________________________________________________________________
# 1   | 3                            | (17 * 3) mod 61                  | 51                   | 0.836                               | 83.61%
# 2   | 51                           | (17 * 51) mod 61                 | 13                   | 0.213                               | 21.31%
# 3   | 13                           | (17 * 13) mod 61                 | 38                   | 0.623                               | 62.3%
# 4   | 38                           | (17 * 38) mod 61                 | 36                   | 0.59                                | 59.02%
# ...

# %% [markdown]
# 1. Header Tabel
#
#
#
# *   Berfungsi untuk membuat header tabel dengan nama kolom yang sesuai dengan data yang akan ditampilkan.
# *   Format:
#     *   {:<3}: Mengatur kolom pertama (indeks i) dengan lebar 3 karakter, rata kiri.
#     *   {:<28}, {:<32}, {:<20}, {:<35}, {:<10}: Mengatur lebar kolom berikutnya untuk memastikan data terlihat rapi dan sejajar.
# *   Kolom Yang Ditampilkan
#     *   i: Indeks iterasi.
#     *   zi-1 (Bilangan Sebelumnya): Nilai bilangan acak sebelumnya (z i−1).
#     *   rumus zi = (17, zi-1) mod 61: Formula perhitungan untuk menghasilkan zi.
#     *   z (Bilangan Acak): Nilai bilangan acak (zi).
#     *   ui = zi/61 (Bilangan Acak Seragam): Nilai bilangan seragam (ui)
#     *   % (Persentase): Nilai ui dalam bentuk persentase.

# %% [markdown]
# 2. Pembatas Tabel
#
#   print("_" * 150)
#
#   Fungsi:
# *   Menambahkan garis pembatas di bawah header untuk memisahkan nama kolom dari data tabel.
# *   150: Panjang garis disesuaikan dengan total lebar tabel untuk menjaga keselarasan.

# %% [markdown]
# 3. Menampilkan Data
#
#
# *   for row in results: Melakukan iterasi untuk setiap elemen (baris) dalam daftar results.
# *   Format data
#   *   row[0]: Menampilkan indeks iterasi (i).
#   *   row[1]: Bilangan sebelumnya (zi-1).
#   *   row[2]: Rumus perhitungan (17 * zi-1 mod61).
#   *   row[3]: Nilai bilangan acak (zi).
#   *   row[4]: Nilai seragam (ui) dibulatkan hingga 3 desimal.
#   *   row[5]: Nilai ui dalam bentuk persentase.
# *   Pengaturan kolom
#
#   Setiap kolom memiliki lebar yang ditentukan untuk memastikan data rata kiri dan sejajar dengan header.

# %% [markdown]
# **5. Output Dalam Bentuk Grafik**

# %%
iterasi = [row[0] for row in results]
value = [row[4] for row in results]

plt.figure(figsize=(10, 6))
plt.plot(iterasi, value, marker='o', linestyle='-', color='b', label='Nilai Ui')
plt.axhline(y=1, color='r', linestyle='--', label='Ui = 1 (Guaranteed)')
plt.title("Grafik Bilangan Acak Seragam (Ui) dari LCG")
plt.xlabel("Iterasi")
plt.ylabel("Nilai Ui")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Bagian grafik ini membuat plot untuk nilai Ui yang dihitung dari Linear Congruential Generator (LCG) selama 90 iterasi:
#
# 1. Data untuk Grafik: Mengambil iterasi dan nilai Ui dari hasil perhitungan.
# 2. Plotting: plt.plot() menggambar grafik dengan iterasi di sumbu X dan nilai Ui di sumbu Y, menggunakan titik marker dan garis biru.
# 3. Garis Horizontal: Menambahkan garis merah di Ui = 1 pada iterasi ke-90 untuk menandakan bahwa nilai Ui dijamin menjadi 1.
# 4. Judul dan Label: Menambahkan judul, label sumbu X (Iterasi), dan label sumbu Y (Nilai Ui).
# 5. Grid dan Legenda: Menambahkan grid untuk kemudahan membaca dan legenda untuk membedakan dua garis.
#
# Grafik ini menunjukkan perubahan nilai Ui selama 90 iterasi LCG.

# %% [markdown]
# **Dega Megananda Putra - 301220060 - IF5A**
